# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor

# %%
diens_tich = [100, 120, 130, 155, 180, 200, 220, 240, 250, 260]
so_phong = [3, 3, 3, 4, 4, 4, 5, 5, 5, 6]
gia_tri_thuc_te = [250, 300, 320, 370, 400, 450, 500, 550, 600, 620]
gia_tri_du_doan = knn_regressor.predict(list(zip(diens_tich, so_phong)))

# Dữ liệu để dự đoán
diens_tich_du_doan = [210, 300, 150]
so_phong_du_doan = [4, 2, 3]
gia_tri_du_doan_moi = knn_regressor.predict(list(zip(diens_tich_du_doan, so_phong_du_doan)))

# In ra giá trị dự đoán cho dữ liệu mới
print("\nGiá trị dự đoán cho dữ liệu mới:")
for i, pred in enumerate(gia_tri_du_doan_moi):
    print(f"Căn nhà mới có diện tích {diens_tich_du_doan[i]} và số phòng {so_phong_du_doan[i]}: {pred}")

# Vẽ biểu đồ
plt.figure(figsize=(10, 6))

# Biểu đồ giá trị thực tế
plt.scatter(diens_tich, gia_tri_thuc_te, color='blue', label='Thực tế')

# Biểu đồ giá trị dự đoán cho dữ liệu đã cho
plt.scatter(diens_tich, gia_tri_du_doan, color='red', marker='x', label='Dự đoán (đã cho)')

# Biểu đồ giá trị dự đoán cho dữ liệu mới
plt.scatter(diens_tich_du_doan, gia_tri_du_doan_moi, color='green', marker='o', label='Dự đoán (mới)')

plt.xlabel('Diện tích')
plt.ylabel('Giá trị')
plt.title('Dự đoán giá trị của căn nhà bằng KNN Regression')
plt.legend()
plt.show()
# Out:
# Giá trị dự đoán cho dữ liệu mới:
# Căn nhà mới có diện tích 210 và số phòng 4: 450.0
# Căn nhà mới có diện tích 300 và số phòng 2: 590.0
# Căn nhà mới có diện tích 150 và số phòng 3: 330.0
